# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/Colab Notebooks/BAThesis/"

# %%
plot_text_size = 14

# %% [markdown]
# #Volatility

# %% [markdown]
# ##VIX 2014-2024

# %%
df_vix = pd.read_csv(path + "CBOE_SP500_VIX.csv")

# %%
df_vix
# Out:
#             Date    vix
# 0     2014-01-02  14.23
# 1     2014-01-03  13.76
# 2     2014-01-06  13.55
# 3     2014-01-07  12.92
# 4     2014-01-08  12.87
# ...          ...    ...
# 2526  2023-12-22  13.03
# 2527  2023-12-26  12.99
# 2528  2023-12-27  12.43
# 2529  2023-12-28  12.47
# 2530  2023-12-29  12.45
#
# [2531 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# convert date column to datetime
df_vix['Date'] = pd.to_datetime(df_vix['Date'])

#theme
sns.set_theme(style="whitegrid")

#plot
plt.figure(figsize=(10, 6))
sns.lineplot(x='Date', y='vix', data=df_vix, markersize=8, color='b', linewidth=2)
plt.xlabel('Date', fontsize=plot_text_size)
plt.ylabel('VIX', fontsize=plot_text_size)
plt.tight_layout()
plt.show()

# %%
vix_mean= df_vix['vix'].mean()
vix_mean
# Out:
# 18.135850474683544

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# set theme for sns plots
sns.set_theme(style="whitegrid")

# create figure and axis
fig, ax = plt.subplots()

# plot VIX line
ax.plot(df_vix['Date'], df_vix['vix'], linestyle='-', linewidth=1, color='black', label='VIX')

# plot mean VIX line
plt.axhline(df_vix['vix'].mean(), color='black', linestyle='--', label=f'Mean VIX:{df_vix["vix"].mean():.2f}')

# set y-axis limits
ax.set_ylim(bottom=0, top=100)

# display legend
ax.legend(frameon=True, fontsize=plot_text_size)

# adjust layout
plt.tight_layout()
# set grid style
plt.grid(linestyle='dotted')

# save plot
plt.savefig(path+'VIX_14_21', dpi=500)

# display plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# set theme for sns plots
sns.set_theme(style="whitegrid")

# create figure and axis
fig, ax = plt.subplots()

# plot VIX line
ax.plot(df_vix['Date'], df_vix['vix'], linestyle='-', linewidth=1, color='black', label='VIX')

# plot mean VIX line
plt.axhline(df_vix['vix'].mean(), color='black', linestyle='--', label=f'Mean VIX:{df_vix["vix"].mean():.2f}')

# display legend
ax.legend(loc='upper left', frameon=True, fontsize=plot_text_size)

# adjust layout
plt.tight_layout()
# set grid style
plt.grid(linestyle='dotted')

# save plot
plt.savefig(path+'VIX_14_21_zoom', dpi=500)

# display plot
plt.show()

# %% [markdown]
# ## Low Volatility

# %% [markdown]
# ### VIX 2021-2023

# %%
# filter
df_vix_filtered = df_vix[(df_vix['Date'] >= '2021-01-01') & (df_vix['Date'] <= '2022-12-31')]

# %%
df_vix_filtered
# Out:
#            Date    vix
# 1763 2021-01-04  26.97
# 1764 2021-01-05  25.34
# 1765 2021-01-06  25.07
# 1766 2021-01-07  22.37
# 1767 2021-01-08  21.56
# ...         ...    ...
# 2269 2022-12-23  20.87
# 2270 2022-12-27  21.65
# 2271 2022-12-28  22.14
# 2272 2022-12-29  21.44
# 2273 2022-12-30  21.67
#
# [511 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.dates import DateFormatter, YearLocator

# set theme for sns plots
sns.set_theme(style="whitegrid")

# create figure and axis
fig, ax = plt.subplots()

# plot the VIX over time
ax.plot(df_vix_filtered['Date'], df_vix_filtered['vix'], linestyle='-', linewidth=1, color='black', label='VIX')

# add a horizontal line at the mean VIX
plt.axhline(df_vix_filtered['vix'].mean(), color='black', linestyle='--', label=f'Mean VIX: {df_vix_filtered["vix"].mean():.2f}')

# set y-axis limits
ax.set_ylim(bottom=0, top=100)

# date formatting to show only year
ax.xaxis.set_major_formatter(DateFormatter('%Y'))

# set x-axis major locator to YearLocator to show ticks only at the start of each year
ax.xaxis.set_major_locator(YearLocator())

# set legend
ax.legend(loc='upper left', frameon=True, fontsize=plot_text_size)

# layout adjustments and save
plt.tight_layout()
plt.grid(linestyle='dotted')
plt.savefig(path+'VIX_21_23.png', dpi=500)  # adjust path as needed

# display plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.dates import DateFormatter, YearLocator

# set theme for sns plots
sns.set_theme(style="whitegrid")

# create figure and axis
fig, ax = plt.subplots()

# plot the VIX over time
ax.plot(df_vix_filtered['Date'], df_vix_filtered['vix'], linestyle='-', linewidth=1, color='black', label='VIX')

# add a horizontal line at the mean VIX
plt.axhline(df_vix_filtered['vix'].mean(), color='black', linestyle='--', label=f'Mean VIX: {df_vix_filtered["vix"].mean():.2f}')

# set y-axis limits
ax.set_ylim(bottom=0, top=50)

# date formatting to show only year
ax.xaxis.set_major_formatter(DateFormatter('%Y'))

# set x-axis major locator to YearLocator to show ticks only at the start of each year
ax.xaxis.set_major_locator(YearLocator())

# set legend
ax.legend(loc='upper left', frameon=True, fontsize=plot_text_size)

# layout adjustments and save
plt.tight_layout()
plt.grid(linestyle='dotted')
plt.savefig(path+'VIX_21_23_zoom.png', dpi=500)  # adjust path as needed

# display plot
plt.show()

# %% [markdown]
# ###VIX 2018-2020

# %%
# filter
df_vix_filtered2 = df_vix[(df_vix['Date'] >= '2018-01-01') & (df_vix['Date'] <= '2019-12-31')]

# %%
df_vix_filtered2
# Out:
#            Date    vix
# 1007 2018-01-02   9.77
# 1008 2018-01-03   9.15
# 1009 2018-01-04   9.22
# 1010 2018-01-05   9.22
# 1011 2018-01-08   9.52
# ...         ...    ...
# 1505 2019-12-24  12.67
# 1506 2019-12-26  12.65
# 1507 2019-12-27  13.43
# 1508 2019-12-30  14.82
# 1509 2019-12-31  13.78
#
# [503 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.dates import DateFormatter, YearLocator

# set theme for sns plots
sns.set_theme(style="whitegrid")

# create figure and axis
fig, ax = plt.subplots()

# plot the VIX over time
ax.plot(df_vix_filtered2['Date'], df_vix_filtered2['vix'], linestyle='-', linewidth=1, color='black', label='VIX')

# add a horizontal line at the mean VIX
plt.axhline(df_vix_filtered2['vix'].mean(), color='black', linestyle='--', label=f'Mean VIX:{df_vix_filtered2["vix"].mean():.2f}')

# set y-axis limits
ax.set_ylim(bottom=0, top=100)

# date formatting to show only year
ax.xaxis.set_major_formatter(DateFormatter('%Y'))

# set x-axis major locator to YearLocator to show ticks only at the start of each year
ax.xaxis.set_major_locator(YearLocator())

# set legend
ax.legend(loc='upper left', frameon=True, fontsize=plot_text_size)

# layout adjustments and save
plt.tight_layout()
plt.grid(linestyle='dotted')
plt.savefig(path+'VIX_18_20', dpi=500)

# display plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.dates import DateFormatter, YearLocator

# set theme for sns plots
sns.set_theme(style="whitegrid")

# create figure and axis
fig, ax = plt.subplots()

# plot the VIX over time
ax.plot(df_vix_filtered2['Date'], df_vix_filtered2['vix'], linestyle='-', linewidth=1, color='black', label='VIX')

# add a horizontal line at the mean VIX
plt.axhline(df_vix_filtered2['vix'].mean(), color='black', linestyle='--', label=f'Mean VIX:{df_vix_filtered2["vix"].mean():.2f}')

# set y-axis limits
ax.set_ylim(bottom=0, top=50)

# date formatting to show only year
ax.xaxis.set_major_formatter(DateFormatter('%Y'))

# set x-axis major locator to YearLocator to show ticks only at the start of each year
ax.xaxis.set_major_locator(YearLocator())

# set legend
ax.legend(loc='upper left', frameon=True, fontsize=plot_text_size)

# layout adjustments
plt.tight_layout()
plt.grid(linestyle='dotted')

# save plot
plt.savefig(path+'VIX_18_20_zoom', dpi=500)

# display plot
plt.show()

# %% [markdown]
# ## High Volatility

# %% [markdown]
# ### VIX 2020

# %%
df_vix_filtered3 = df_vix[(df_vix['Date'] >= '2020-01-01') & (df_vix['Date'] <= '2020-12-31')]

# %%
df_vix_filtered3
# Out:
#            Date    vix
# 1510 2020-01-02  12.47
# 1511 2020-01-03  14.02
# 1512 2020-01-06  13.85
# 1513 2020-01-07  13.79
# 1514 2020-01-08  13.45
# ...         ...    ...
# 1758 2020-12-24  21.53
# 1759 2020-12-28  21.70
# 1760 2020-12-29  23.08
# 1761 2020-12-30  22.77
# 1762 2020-12-31  22.75
#
# [253 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib.dates import DateFormatter, MonthLocator

# set theme for sns plots
sns.set_theme(style="whitegrid")

# create figure and axis
fig, ax = plt.subplots()

# plot the VIX over time
ax.plot(df_vix_filtered3['Date'], df_vix_filtered3['vix'], linestyle='-', linewidth=1, color='black', label='VIX')  # other styles: --

# add a horizontal line at the mean VIX
plt.axhline(df_vix_filtered3['vix'].mean(), color='black', linestyle='--', label=f'Mean VIX:{df_vix_filtered3["vix"].mean():.2f}')

# set y-axis limits
ax.set_ylim(bottom=0, top=100)

# date formatting to show only month
ax.xaxis.set_major_formatter(DateFormatter('%b'))

# set x-axis major locator to MonthLocator to show ticks only when the month changes
ax.xaxis.set_major_locator(MonthLocator())

# set legend
ax.legend(loc='upper left', frameon=True, fontsize=plot_text_size)

# layout adjustments
plt.tight_layout()
plt.grid(linestyle='dotted')

# save plot
plt.savefig(path+'VIX_20', dpi=500)

# display plot
plt.show()

# %% [markdown]
# ### VIX 2020 Feb-April

# %%
df_vix_filtered4 = df_vix[(df_vix['Date'] >= '2020-02-01') & (df_vix['Date'] <= '2020-03-31')]

# %%
df_vix_filtered4
# Out:
#            Date    vix
# 1531 2020-02-03  17.97
# 1532 2020-02-04  16.05
# 1533 2020-02-05  15.15
# 1534 2020-02-06  14.96
# 1535 2020-02-07  15.47
# 1536 2020-02-10  15.04
# 1537 2020-02-11  15.18
# 1538 2020-02-12  13.74
# 1539 2020-02-13  14.15
# 1540 2020-02-14  13.68
# 1541 2020-02-18  14.83
# 1542 2020-02-19  14.38
# 1543 2020-02-20  15.56
# 1544 2020-02-21  17.08
# 1545 2020-02-24  25.03
# 1546 2020-02-25  27.85
# 1547 2020-02-26  27.56
# 1548 2020-02-27  39.16
# 1549 2020-02-28  40.11
# 1550 2020-03-02  33.42
# 1551 2020-03-03  36.82
# 1552 2020-03-04  31.99
# 1553 2020-03-05  39.62
# 1554 2020-03-06  41.94
# 1555 2020-03-09  54.46
# 1556 2020-03-10  47.30
# 1557 2020-03-11  53.90
# 1558 2020-03-12  75.47
# 1559 2020-03-13  57.83
# 1560 2020-03-16  82.69
# 1561 2020-03-17  75.91
# 1562 2020-03-18  76.45
# 1563 2020-03-19  72.00
# 1564 2020-03-20  66.04
# 1565 2020-03-23  61.59
# 1566 2020-03-24  61.67
# 1567 2020-03-25  63.95
# 1568 2020-03-26  61.00
# 1569 2020-03-27  65.54
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.dates as mdates

# set theme for sns plots
sns.set_theme(style="whitegrid")

# create figure and axis
fig, ax = plt.subplots()

# plot the VIX over time
ax.plot(df_vix_filtered4['Date'], df_vix_filtered4['vix'], linestyle='-', linewidth=1, color='black', label='VIX')  # other styles: --

# add a horizontal line at the mean VIX
plt.axhline(df_vix_filtered4['vix'].mean(), color='black', linestyle='--', label=f'Mean VIX:{df_vix_filtered4["vix"].mean():.2f}')

# set x-axis date formatting to show month and day
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# set y-axis limits
ax.set_ylim(bottom=0, top=100)

# date formatting to show only month
ax.xaxis.set_major_formatter(DateFormatter('%b'))

# set x-axis major locator to MonthLocator to show ticks only when the month changes
ax.xaxis.set_major_locator(MonthLocator())

# set legend
ax.legend(loc='upper left', frameon=True, fontsize=plot_text_size)

# layout adjustments
plt.tight_layout()
plt.grid(linestyle='dotted')

# save plot
plt.savefig(path+'VIX_20_Feb_Mar', dpi=500)

# display plot
plt.show()

# %% [markdown]
# #Interest Rate

# %%
df_treasury = pd.read_csv(path + "US_Treasury_Index_T30_T90.csv")

# %%
df_treasury
# Out:
#          caldt    t90ret    t30ret
# 0   2019-12-31  0.001498  0.001431
# 1   2020-01-31  0.001308  0.001164
# 2   2020-02-28  0.001513  0.001208
# 3   2020-03-31  0.003067  0.001268
# 4   2020-04-30  0.000116  0.000003
# 5   2020-05-29  0.000029  0.000059
# 6   2020-06-30  0.000155  0.000111
# 7   2020-07-31  0.000330  0.000096
# 8   2020-08-31  0.000069  0.000079
# 9   2020-09-30  0.000099  0.000076
# 10  2020-10-30  0.000067  0.000073
# 11  2020-11-30  0.000096  0.000066
# 12  2020-12-31  0.000054  0.000060
# 13  2021-01-29  0.000110  0.000046
# 14  2021-02-26  0.000080  0.000045
# 15  2021-03-31  0.000090  0.000027
# 16  2021-04-30  0.000146  0.000014
# 17  2021-05-28  0.000025  0.000005
# 18  2021-06-30 -0.000045  0.000004
# 19  2021-07-30  0.000029  0.000031
# 20  2021-08-31  0.000030  0.000049
# 21  2021-09-30  0.000080  0.000033
# 22  2021-10-29 -0.000034  0.000037
# 23  2021-11-30  0.000073  0.000044
# 24  2021-12-31  0.000081  0.000067
# 25  2022-01-31 -0.000035  0.000044
# ...

# %%
df_treasury['caldt'] = pd.to_datetime(df_treasury['caldt'])
df_treasury.rename(columns={'caldt': 'Date'}, inplace=True)

# %%
df_treasury['Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 38 entries, 0 to 37
# Series name: Date
# Non-Null Count  Dtype
# --------------  -----
# 38 non-null     datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 432.0 bytes

# %%
df_treasury
# Out:
#          Date    t90ret    t30ret
# 0  2019-12-31  0.001498  0.001431
# 1  2020-01-31  0.001308  0.001164
# 2  2020-02-28  0.001513  0.001208
# 3  2020-03-31  0.003067  0.001268
# 4  2020-04-30  0.000116  0.000003
# 5  2020-05-29  0.000029  0.000059
# 6  2020-06-30  0.000155  0.000111
# 7  2020-07-31  0.000330  0.000096
# 8  2020-08-31  0.000069  0.000079
# 9  2020-09-30  0.000099  0.000076
# 10 2020-10-30  0.000067  0.000073
# 11 2020-11-30  0.000096  0.000066
# 12 2020-12-31  0.000054  0.000060
# 13 2021-01-29  0.000110  0.000046
# 14 2021-02-26  0.000080  0.000045
# 15 2021-03-31  0.000090  0.000027
# 16 2021-04-30  0.000146  0.000014
# 17 2021-05-28  0.000025  0.000005
# 18 2021-06-30 -0.000045  0.000004
# 19 2021-07-30  0.000029  0.000031
# 20 2021-08-31  0.000030  0.000049
# 21 2021-09-30  0.000080  0.000033
# 22 2021-10-29 -0.000034  0.000037
# 23 2021-11-30  0.000073  0.000044
# 24 2021-12-31  0.000081  0.000067
# 25 2022-01-31 -0.000035  0.000044
# ...

# %%
import pandas as pd

df_treasury['Date'] = pd.to_datetime(df_treasury['Date'])
df_treasury.set_index('Date', inplace=True)
df_treasury_filled = df_treasury.resample('D').ffill()

# %%
df_treasury_filled
# Out:
#               t90ret    t30ret
# Date
# 2019-12-31  0.001498  0.001431
# 2020-01-01  0.001498  0.001431
# 2020-01-02  0.001498  0.001431
# 2020-01-03  0.001498  0.001431
# 2020-01-04  0.001498  0.001431
# ...              ...       ...
# 2023-01-27  0.003280  0.003379
# 2023-01-28  0.003280  0.003379
# 2023-01-29  0.003280  0.003379
# 2023-01-30  0.003280  0.003379
# 2023-01-31  0.003462  0.003506
#
# [1128 rows x 2 columns]

# %% [markdown]
# # Merge VIX and Interest rate

# %%
# merge
merged_df = pd.merge(df_vix, df_treasury_filled, on='Date', how='left')

# %%
merged_df = merged_df[(merged_df['Date'] >= '2019-12-31') & (merged_df['Date'] <= '2022-12-31')]

# %%
merged_df
# Out:
#            Date    vix    t90ret    t30ret
# 1509 2019-12-31  13.78  0.001498  0.001431
# 1510 2020-01-02  12.47  0.001498  0.001431
# 1511 2020-01-03  14.02  0.001498  0.001431
# 1512 2020-01-06  13.85  0.001498  0.001431
# 1513 2020-01-07  13.79  0.001498  0.001431
# ...         ...    ...       ...       ...
# 2269 2022-12-23  20.87  0.003114  0.002856
# 2270 2022-12-27  21.65  0.003114  0.002856
# 2271 2022-12-28  22.14  0.003114  0.002856
# 2272 2022-12-29  21.44  0.003114  0.002856
# 2273 2022-12-30  21.67  0.003280  0.003379
#
# [765 rows x 4 columns]

# %% [markdown]
# # Options DataFrame

# %%
df_options = pd.read_csv(path + "options_2020_2023.csv")

# %%
df_options
# Out:
#                 date      exdate   last_date cp_flag  strike_price  best_bid  \
# 0         2020-01-02  2020-02-21         NaN       C       1775000    1472.8
# 1         2020-01-02  2020-02-21         NaN       C       1800000    1447.8
# 2         2020-01-02  2020-02-21         NaN       C       1825000    1422.9
# 3         2020-01-02  2020-02-21         NaN       C       1850000    1398.0
# 4         2020-01-02  2020-02-21         NaN       C       1875000    1373.1
# ...              ...         ...         ...     ...           ...       ...
# 14395083  2022-12-30  2023-12-29  2022-12-29       P       5000000    1000.2
# 14395084  2022-12-30  2023-12-29         NaN       P       5025000    1022.0
# 14395085  2022-12-30  2023-12-29  2022-12-29       P       5200000    1178.2
# 14395086  2022-12-30  2023-12-29         NaN       P       5400000    1359.3
# 14395087  2022-12-30  2023-12-29  2022-12-27       P        800000       1.7
#
# ...

# %%
# drop columns
df_options = df_options.drop(columns= ['index_flag','optionid','industry_group', 'exercise_style'])

# %%
# drop NaN
df_options = df_options.dropna(subset=['impl_volatility'])

# %%
# get calls
calls = df_options[df_options['cp_flag'] == 'C']

# %%
calls = calls.dropna(subset=['last_date'])

# %%
calls
# Out:
#                 date      exdate   last_date cp_flag  strike_price  best_bid  \
# 135       2020-01-02  2020-02-21  2019-09-25       C       2650000     601.9
# 149       2020-01-02  2020-02-21  2019-12-13       C       2690000     562.4
# 152       2020-01-02  2020-02-21  2019-12-30       C       2700000     552.5
# 156       2020-01-02  2020-02-21  2019-12-13       C       2710000     542.7
# 159       2020-01-02  2020-02-21  2019-12-30       C       2720000     532.8
# ...              ...         ...         ...     ...           ...       ...
# 14395013  2022-12-30  2023-12-29  2022-12-27       C       4600000      88.4
# 14395014  2022-12-30  2023-12-29  2022-12-30       C       4800000      49.7
# 14395015  2022-12-30  2023-12-29  2022-12-28       C       5000000      27.3
# 14395016  2022-12-30  2023-12-29  2022-12-22       C       5025000      25.4
# 14395018  2022-12-30  2023-12-29  2022-12-29       C       5400000       8.9
#
# ...

# %%
calls['last_date'] = pd.to_datetime(calls['last_date'])
calls['date'] = pd.to_datetime(calls['date'])

# %%
# calculate last date traded
calls['days_since_last_trade'] = calls['date'] - calls['last_date']

# %%
# get active calls
ctive_calls = calls[calls['days_since_last_trade'] <= pd.Timedelta(days=3)]

# %%
active_calls
# Out:
#                date      exdate  last_date cp_flag  strike_price  best_bid  \
# 152      2020-01-02  2020-02-21 2019-12-30       C       2700000     552.5
# 159      2020-01-02  2020-02-21 2019-12-30       C       2720000     532.8
# 191      2020-01-02  2020-02-21 2019-12-30       C       2800000     454.2
# 215      2020-01-02  2020-02-21 2019-12-30       C       2850000     405.5
# 251      2020-01-02  2020-02-21 2020-01-02       C       2950000     311.7
# ...             ...         ...        ...     ...           ...       ...
# 14395012 2022-12-30  2023-12-29 2022-12-30       C       4500000     115.2
# 14395013 2022-12-30  2023-12-29 2022-12-27       C       4600000      88.4
# 14395014 2022-12-30  2023-12-29 2022-12-30       C       4800000      49.7
# 14395015 2022-12-30  2023-12-29 2022-12-28       C       5000000      27.3
# 14395018 2022-12-30  2023-12-29 2022-12-29       C       5400000       8.9
#
# ...

# %%
active_calls = active_calls.drop(columns=['days_since_last_trade','last_date'])

# %%
active_calls
# Out:
#                date      exdate cp_flag  strike_price  best_bid  best_offer  \
# 152      2020-01-02  2020-02-21       C       2700000     552.5       562.1
# 159      2020-01-02  2020-02-21       C       2720000     532.8       542.4
# 191      2020-01-02  2020-02-21       C       2800000     454.2       463.8
# 215      2020-01-02  2020-02-21       C       2850000     405.5       415.0
# 251      2020-01-02  2020-02-21       C       2950000     311.7       316.1
# ...             ...         ...     ...           ...       ...         ...
# 14395012 2022-12-30  2023-12-29       C       4500000     115.2       118.1
# 14395013 2022-12-30  2023-12-29       C       4600000      88.4        91.1
# 14395014 2022-12-30  2023-12-29       C       4800000      49.7        52.1
# 14395015 2022-12-30  2023-12-29       C       5000000      27.3        29.1
# 14395018 2022-12-30  2023-12-29       C       5400000       8.9         9.7
#
# ...

# %%
# calculate price
active_calls["price"]= (active_calls["best_bid"] + active_calls["best_offer"])/2

# %%
#according to option metrics it is times  10000
active_calls['strike_price'] = active_calls['strike_price']/1000

# %%
from datetime import datetime

# maturity
active_calls['maturity'] = (pd.to_datetime(active_calls['exdate']) - pd.to_datetime(active_calls['date'])).dt.days

# %%
active_calls
# Out:
#                date      exdate cp_flag  strike_price  best_bid  best_offer  \
# 152      2020-01-02  2020-02-21       C        2700.0     552.5       562.1
# 159      2020-01-02  2020-02-21       C        2720.0     532.8       542.4
# 191      2020-01-02  2020-02-21       C        2800.0     454.2       463.8
# 215      2020-01-02  2020-02-21       C        2850.0     405.5       415.0
# 251      2020-01-02  2020-02-21       C        2950.0     311.7       316.1
# ...             ...         ...     ...           ...       ...         ...
# 14395012 2022-12-30  2023-12-29       C        4500.0     115.2       118.1
# 14395013 2022-12-30  2023-12-29       C        4600.0      88.4        91.1
# 14395014 2022-12-30  2023-12-29       C        4800.0      49.7        52.1
# 14395015 2022-12-30  2023-12-29       C        5000.0      27.3        29.1
# 14395018 2022-12-30  2023-12-29       C        5400.0       8.9         9.7
#
# ...

# %%
# filter out options with time to maturity over 30
active_calls = active_calls[active_calls['maturity'] <= 30]

# %%
active_calls
# Out:
#                date      exdate cp_flag  strike_price  best_bid  best_offer  \
# 611      2020-01-02  2020-01-17       C        2900.0    354.00      361.10
# 639      2020-01-02  2020-01-17       C        2950.0    304.30      311.40
# 642      2020-01-02  2020-01-17       C        2965.0    289.40      296.50
# 649      2020-01-02  2020-01-17       C        2970.0    284.40      291.50
# 650      2020-01-02  2020-01-17       C        2975.0    279.50      286.50
# ...             ...         ...     ...           ...       ...         ...
# 14388463 2022-12-30  2023-01-27       C        4275.0      1.05        1.15
# 14388464 2022-12-30  2023-01-27       C        4300.0      0.80        0.95
# 14388465 2022-12-30  2023-01-27       C        4350.0      0.50        0.65
# 14388466 2022-12-30  2023-01-27       C        4400.0      0.35        0.45
# 14388467 2022-12-30  2023-01-27       C        4600.0      0.10        0.20
#
# ...

# %%
maturity_counts = active_calls['maturity'].value_counts()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# set theme for sns plots
sns.set_theme(style="whitegrid")

# create figure and axis
fig, ax = plt.subplots()

# plot bar chart for maturity counts
ax.bar(maturity_counts.index, maturity_counts.values, color='#646464', edgecolor='black')

# set x-axis label
ax.set_xlabel('Maturity', fontsize=plot_text_size)
# set y-axis label
ax.set_ylabel('Number of Options', fontsize=plot_text_size)

# layout adjustments
plt.tight_layout()
plt.grid(linestyle='dotted')

# display plot
plt.show()

# %% [markdown]
# # Merge Interest Rate and Active Calls

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 765 entries, 1509 to 2273
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    765 non-null    datetime64[ns]
#  1   vix     762 non-null    float64
#  2   t90ret  765 non-null    float64
#  3   t30ret  765 non-null    float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 29.9 KB

# %%
df_treasury_filled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1128 entries, 2019-12-31 to 2023-01-31
# Freq: D
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   t90ret  1128 non-null   float64
#  1   t30ret  1128 non-null   float64
# dtypes: float64(2)
# memory usage: 26.4 KB

# %%
nan_vix_rows = merged_df[pd.isna(merged_df['vix'])]

# %%
merged_df.loc[merged_df['Date'] == '2021-04-02']
# Out:
#            Date  vix   t90ret    t30ret
# 1825 2021-04-02  NaN  0.00009  0.000027

# %%
nan_vix_rows
# Out:
#            Date  vix    t90ret    t30ret
# 1825 2021-04-02  NaN  0.000090  0.000027
# 1904 2021-07-25  NaN -0.000045  0.000004
# 2012 2021-12-24  NaN  0.000073  0.000044

# %%
active_calls.loc[active_calls['date'] == '2021-07-25']
# Out:
# Empty DataFrame
# Columns: [date, exdate, cp_flag, strike_price, best_bid, best_offer, impl_volatility, delta, gamma, vega, theta, ticker, issuer, price, maturity]
# Index: []

# %%
active_calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1096861 entries, 611 to 14388467
# Data columns (total 15 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   date             1096861 non-null  datetime64[ns]
#  1   exdate           1096861 non-null  object
#  2   cp_flag          1096861 non-null  object
#  3   strike_price     1096861 non-null  float64
#  4   best_bid         1096861 non-null  float64
#  5   best_offer       1096861 non-null  float64
#  6   impl_volatility  1096861 non-null  float64
#  7   delta            1096861 non-null  float64
#  8   gamma            1096861 non-null  float64
#  9   vega             1096861 non-null  float64
#  10  theta            1096861 non-null  float64
#  11  ticker           1096861 non-null  object
#  12  issuer           1096861 non-null  object
#  13  price            1096861 non-null  float64
#  14  maturity         1096861 non-null  int64
# ...

# %%
merged_df.rename(columns={'Date': 'date'}, inplace=True)

# %%
final_df = pd.merge(active_calls, merged_df, on='date', how='left')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1096861 entries, 0 to 1096860
# Data columns (total 18 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   date             1096861 non-null  datetime64[ns]
#  1   exdate           1096861 non-null  object
#  2   cp_flag          1096861 non-null  object
#  3   strike_price     1096861 non-null  float64
#  4   best_bid         1096861 non-null  float64
#  5   best_offer       1096861 non-null  float64
#  6   impl_volatility  1096861 non-null  float64
#  7   delta            1096861 non-null  float64
#  8   gamma            1096861 non-null  float64
#  9   vega             1096861 non-null  float64
#  10  theta            1096861 non-null  float64
#  11  ticker           1096861 non-null  object
#  12  issuer           1096861 non-null  object
#  13  price            1096861 non-null  float64
#  14  maturity         1096861 non-null  int64
# ...

# %%
final_df = final_df.drop(columns=['ticker','t90ret','exdate','cp_flag'])

# %%
final_df
# Out:
#               date  strike_price  best_bid  best_offer  impl_volatility  \
# 0       2020-01-02        2900.0    354.00      361.10         0.208176
# 1       2020-01-02        2950.0    304.30      311.40         0.211056
# 2       2020-01-02        2965.0    289.40      296.50         0.207403
# 3       2020-01-02        2970.0    284.40      291.50         0.203951
# 4       2020-01-02        2975.0    279.50      286.50         0.203369
# ...            ...           ...       ...         ...              ...
# 1096856 2022-12-30        4275.0      1.05        1.15         0.176422
# 1096857 2022-12-30        4300.0      0.80        0.95         0.178997
# 1096858 2022-12-30        4350.0      0.50        0.65         0.184808
# 1096859 2022-12-30        4400.0      0.35        0.45         0.191495
# 1096860 2022-12-30        4600.0      0.10        0.20         0.223686
#
#             delta     gamma       vega      theta              issuer  \
# ...

# %% [markdown]
# # Merge S&P 500 Returns and Active Calls

# %%
returns = pd.read_csv(path + "SP500_returns.csv")

# %%
returns
# Out:
#           caldt   spindx    sprtrn
# 0    2020-01-02  3257.85  0.008379
# 1    2020-01-03  3234.85 -0.007060
# 2    2020-01-06  3246.28  0.003533
# 3    2020-01-07  3237.18 -0.002803
# 4    2020-01-08  3253.05  0.004902
# ..          ...      ...       ...
# 771  2023-01-25  4016.22 -0.000182
# 772  2023-01-26  4060.43  0.011008
# 773  2023-01-27  4070.56  0.002495
# 774  2023-01-30  4017.77 -0.012969
# 775  2023-01-31  4076.60  0.014642
#
# [776 rows x 3 columns]

# %%
returns.rename(columns={'caldt': 'date'}, inplace=True)

# %%
returns['date'] = pd.to_datetime(returns['date'])

# %%
returns
# Out:
#           date   spindx    sprtrn
# 0   2020-01-02  3257.85  0.008379
# 1   2020-01-03  3234.85 -0.007060
# 2   2020-01-06  3246.28  0.003533
# 3   2020-01-07  3237.18 -0.002803
# 4   2020-01-08  3253.05  0.004902
# ..         ...      ...       ...
# 771 2023-01-25  4016.22 -0.000182
# 772 2023-01-26  4060.43  0.011008
# 773 2023-01-27  4070.56  0.002495
# 774 2023-01-30  4017.77 -0.012969
# 775 2023-01-31  4076.60  0.014642
#
# [776 rows x 3 columns]

# %%
bsm_df = pd.merge(final_df, returns, on='date', how='left')

# %% [markdown]
# ## Filter Dataset

# %% [markdown]
# Add moneyness

# %%
# moneyness
bsm_df["moneyness"] = bsm_df["spindx"]/bsm_df['strike_price'] #stock/strike price

# %%
# time period
df_model = bsm_df[(bsm_df['date'] >= '2021-01-01') & (bsm_df['date'] <= '2022-12-31')]

# %%
df_model_test_feb_mar =  bsm_df[(bsm_df['date'] >= '2020-02-01') & (bsm_df['date'] <= '2020-03-31')]

# %%
bsm_df
# Out:
#               date  strike_price  best_bid  best_offer  impl_volatility  \
# 0       2020-01-02        2900.0    354.00      361.10         0.208176
# 1       2020-01-02        2950.0    304.30      311.40         0.211056
# 2       2020-01-02        2965.0    289.40      296.50         0.207403
# 3       2020-01-02        2970.0    284.40      291.50         0.203951
# 4       2020-01-02        2975.0    279.50      286.50         0.203369
# ...            ...           ...       ...         ...              ...
# 1096856 2022-12-30        4275.0      1.05        1.15         0.176422
# 1096857 2022-12-30        4300.0      0.80        0.95         0.178997
# 1096858 2022-12-30        4350.0      0.50        0.65         0.184808
# 1096859 2022-12-30        4400.0      0.35        0.45         0.191495
# 1096860 2022-12-30        4600.0      0.10        0.20         0.223686
#
#             delta     gamma       vega      theta              issuer  \
# ...

# %% [markdown]
# ## Volatility Annual

# %%
import pandas as pd
import numpy as np

# annual vola
annual_volatility_by_year = bsm_df.groupby(bsm_df['date'].dt.year)['sprtrn'].std() * np.sqrt(252)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# setting the visual style for the plots
sns.set(style='whitegrid')

# creating a new plot with defined dimensions
plt.figure(figsize=(10, 6))

# plotting the annual volatility as a bar chart
annual_volatility_by_year.plot(kind='bar', color='#646464', edgecolor='black', label="Ø Annual Volatility S&P500")

# ensure the x-tick labels are horizontal
plt.xticks(ticks=range(len(annual_volatility_by_year)), labels=annual_volatility_by_year.index, rotation=0, fontsize=plot_text_size)

# hide the original x-axis labels
plt.xlabel('')

# set legend
plt.legend(loc='upper right', frameon=True, fontsize=plot_text_size)

# layout adjustments
plt.tight_layout()
plt.grid(linestyle='dotted')

# save plot
plt.savefig(path+'annual_vola', dpi=500)

# displaying the plot
plt.show()

# %% [markdown]
# ## Volatility Skew

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# filter df for the year 2020
df_filtered = bsm_df[(bsm_df['date'].dt.year) == 2020]

# calculate  average underlying price
underlying_price = df_filtered['spindx'].mean()

# group by strike_price and calculate the average of impl_volatility for each group
df_grouped = df_filtered.groupby('strike_price')['impl_volatility'].mean().reset_index()

# sort the grouped df by strike price
df_sorted = df_grouped.sort_values(by='strike_price')

# setting the visual style of seaborn plots
sns.set(style='whitegrid')

# create a new plot with defined dimensions
plt.figure(figsize=(10, 6))

# plot the average implied volatility against strike price
plt.plot(df_sorted['strike_price'], df_sorted['impl_volatility'], linestyle='-', color='black')

# mark the price of the underlying on the x-axis
plt.axvline(x=underlying_price, color='black', linestyle='--', label=f'Ø Underlying Price ({underlying_price:.2f})')

# set label grid legend
plt.xlabel('Strike Price', fontsize=plot_text_size)
plt.ylabel('Average Implied Volatility', fontsize=plot_text_size)
plt.legend(frameon=True, fontsize=plot_text_size)
plt.grid(linestyle='dotted')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# datetime
bsm_df['date'] = pd.to_datetime(bsm_df['date'])

# initialize the figure and set visual style
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))

# define years to plot and their respective colors and line styles
years = [2020, 2021, 2022]
colors = ['black', '#646464', '#AAAAAA']
line_styles = [':', '--', '-.']

for year, color, line_style in zip(years, colors, line_styles):
    # filter data for the specific year
    df_filtered = bsm_df[bsm_df['date'].dt.year == year]

    # calculate the mean underlying price for the year
    underlying_price = df_filtered['spindx'].mean()

    # group by strike_price and calculate the average of impl_volatility for each group
    df_grouped = df_filtered.groupby('strike_price')['impl_volatility'].mean().reset_index()

    # sort the grouped df by strike price
    df_sorted = df_grouped.sort_values(by='strike_price')

    # plot the volatility skew for the year
    plt.plot(df_sorted['strike_price'], df_sorted['impl_volatility'], linestyle='-', label=f'{year}', color=color)

    # mark the average price of the underlying for the year
    plt.axvline(x=underlying_price, color=color, linestyle=line_style, label=f'Underlying Price')

# setting plot labels and title
plt.xlabel('Strike Price', fontsize=plot_text_size)
plt.ylabel('Average Implied Volatility', fontsize=plot_text_size)
plt.legend(frameon=True, loc='upper right', fontsize=plot_text_size)
plt.grid(True, linestyle='dotted')

# save plot
plt.savefig(path+'volatility_skew', dpi=500)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# datetime
bsm_df['date'] = pd.to_datetime(bsm_df['date'])

# style
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))

# define maturities to plot and their respective colors
maturities = [1, 15, 30]
colors = ['black', '#646464', '#AAAAAA']

for maturity, color in zip(maturities, colors):
    # filter data for the specific year
    df_filtered = bsm_df[bsm_df['date'].dt.year == 2020]
    underlying_price = df_filtered['spindx'].mean()
    df_filtered = df_filtered[df_filtered['maturity'] == maturity]

    # group by strike price and calculate the average of impl_volatility for each group
    df_grouped = df_filtered.groupby('strike_price')['impl_volatility'].mean().reset_index()

    # sort the grouped df by strike price
    df_sorted = df_grouped.sort_values(by='strike_price')

    # plot the volatility skew for the maturity
    plt.plot(df_sorted['strike_price'], df_sorted['impl_volatility'], linestyle='-', label=f'Maturity: {maturity}', color=color)

# mark the average price of the underlying for the year
plt.axvline(x=underlying_price, color='black', linestyle=':', label=f'Underlying Price')

# labels
plt.xlabel('Strike Price', fontsize=plot_text_size)
plt.ylabel('Average Implied Volatility', fontsize=plot_text_size)

# add skewness and kurtosis in box
textstr = '2020'
props = dict(boxstyle='round', edgecolor='gray', alpha=0.5, facecolor='white')

# place the text box
plt.text(0.915, 0.69, textstr, transform=plt.gca().transAxes, fontsize=plot_text_size,
         verticalalignment='top', bbox=props)

# set legend
plt.legend(frameon=True, loc='upper right', fontsize=plot_text_size)
plt.grid(True, linestyle='dotted')

# save plot
plt.savefig(path+'volatility_skew_maturity_2021', dpi=500)

# display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ensure the date column is in datetime format if it isn't already
bsm_df['date'] = pd.to_datetime(bsm_df['date'])

# initialize the figure and set visual style
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))

# define maturities to plot and their respective colors
maturities = [1, 15, 30]
colors = ['black', '#646464', '#AAAAAA']

for maturity, color in zip(maturities, colors):
    # filter data for the specific year
    df_filtered = bsm_df[bsm_df['date'].dt.year == 2021]
    underlying_price = df_filtered['spindx'].mean()
    df_filtered = df_filtered[df_filtered['maturity'] == maturity]

    # group by strike_price and calculate the average of impl_volatility for each group
    df_grouped = df_filtered.groupby('strike_price')['impl_volatility'].mean().reset_index()

    # sort the grouped df by strike price
    df_sorted = df_grouped.sort_values(by='strike_price')

    # plot the volatility skew for the maturity
    plt.plot(df_sorted['strike_price'], df_sorted['impl_volatility'], linestyle='-', label=f'Maturity: {maturity}', color=color)

# mark the average price of the underlying for the year
plt.axvline(x=underlying_price, color='black', linestyle=':', label=f'Underlying Price')

# set x-axis label
plt.xlabel('Strike Price', fontsize=plot_text_size)
# set y-axis label
plt.ylabel('Average Implied Volatility', fontsize=plot_text_size)

# add a text box with the year
textstr = '2021'
props = dict(boxstyle='round', edgecolor='gray', alpha=0.5, facecolor='white')
plt.text(0.915, 0.69, textstr, transform=plt.gca().transAxes, fontsize=plot_text_size, verticalalignment='top', bbox=props)

# set legend
plt.legend(frameon=True, loc='upper right', fontsize=plot_text_size)
plt.grid(True, linestyle='dotted')

# save plot
plt.savefig(path + 'volatility_skew_maturity_2021', dpi=500)

# display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ensure the date column is in datetime format if it isn't already
bsm_df['date'] = pd.to_datetime(bsm_df['date'])

# initialize the figure and set visual style
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))

# define maturities to plot and their respective colors
maturities = [1, 15, 30]
colors = ['black', '#646464', '#AAAAAA']

for maturity, color in zip(maturities, colors):
    # filter data for the specific year
    df_filtered = bsm_df[bsm_df['date'].dt.year == 2022]
    underlying_price = df_filtered['spindx'].mean()
    df_filtered = df_filtered[df_filtered['maturity'] == maturity]

    # group by strike_price and calculate the average of impl_volatility for each group
    df_grouped = df_filtered.groupby('strike_price')['impl_volatility'].mean().reset_index()

    # sort the grouped df by strike price
    df_sorted = df_grouped.sort_values(by='strike_price')

    # plot the volatility skew for the maturity
    plt.plot(df_sorted['strike_price'], df_sorted['impl_volatility'], linestyle='-', label=f'Maturity: {maturity}', color=color)

# mark the average price of the underlying for the year
plt.axvline(x=underlying_price, color='black', linestyle=':', label=f'Underlying Price')

# set x-axis label
plt.xlabel('Strike Price', fontsize=plot_text_size)
# set y-axis label
plt.ylabel('Average Implied Volatility', fontsize=plot_text_size)

# add a text box with the year
textstr = '2022'
props = dict(boxstyle='round', edgecolor='gray', alpha=0.5, facecolor='white')
plt.text(0.915, 0.69, textstr, transform=plt.gca().transAxes, fontsize=plot_text_size, verticalalignment='top', bbox=props)

# set legend
plt.legend(frameon=True, loc='upper right', fontsize=plot_text_size)
plt.grid(True, linestyle='dotted')

# save plot
plt.savefig(path + 'volatility_skew_maturity_2022', dpi=500)

# display the plot
plt.show()

# %% [markdown]
# ## Volatility Term Structure

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# calculate average implied volatility for each maturity
df_grouped = bsm_df.groupby('maturity')['impl_volatility'].mean().reset_index()

# sort by maturity
df_sorted = df_grouped.sort_values(by='maturity')

# style
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))

# plot average implied volatility against maturity
plt.plot(df_sorted['maturity'], df_sorted['impl_volatility'], linestyle='-', color='black')

# labels
plt.xlabel('Maturity', fontsize=plot_text_size)
plt.ylabel('Average implied volatility', fontsize=plot_text_size)

# add grid
plt.grid(linestyle='dotted')

# display plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# initialize the figure and set visual style
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))

# define years to plot and their respective colors
years = [2020, 2021, 2022]
colors = ['black', '#646464', '#AAAAAA']

for year, color in zip(years, colors):
    # filter data for the specific year
    df_filtered = bsm_df[bsm_df['date'].dt.year == year]

    # group by maturity and calculate the average of implied volatility for each group
    df_grouped = df_filtered.groupby('maturity')['impl_volatility'].mean().reset_index()

    # sort the grouped df by maturity
    df_sorted = df_grouped.sort_values(by='maturity')

    # plot the volatility term structure for the year
    plt.plot(df_sorted['maturity'], df_sorted['impl_volatility'], linestyle='-', label=f'{year}', color=color)

# set x-axis label
plt.xlabel('Maturity', fontsize=plot_text_size)
# set y-axis label
plt.ylabel('Average Implied Volatility', fontsize=plot_text_size)

# set legend
plt.legend(frameon=True, loc='upper right', fontsize=plot_text_size)
plt.grid(True, linestyle='dotted')

# save plot
plt.savefig(path + 'volatility_term_structure', dpi=500)

# display the plot
plt.show()

# %% [markdown]
# ## Volatility by direction of return

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# prepare data function that filters and categorizes data
def prepare_data(df, year):
    filtered_df = df[df['date'].dt.year == year].copy()  # create a copy to safely modify data
    filtered_df['Year'] = year  # add a year column
    filtered_df['Direction'] = pd.cut(filtered_df['sprtrn'],
                                      bins=[-float('inf'), 0, float('inf')],
                                      labels=['Negative Return', 'Positive Return'])
    return filtered_df[['Year', 'Direction', 'impl_volatility']]

# assuming bsm_df is defined with the necessary data
# prepare data
data_2020 = prepare_data(bsm_df, 2020)
data_2021 = prepare_data(bsm_df, 2021)
data_2022 = prepare_data(bsm_df, 2022)

# combine the data into one df
combined_data = pd.concat([data_2020, data_2021, data_2022])

# calculate average implied volatility for each direction and year
avg_volatility_direction = combined_data.groupby(['Year', 'Direction'])['impl_volatility'].mean().reset_index()

# plotting
sns.set_theme(style=whitegrid)
# increase the size by adjusting height and aspect
g = sns.catplot(x=Year, y=impl_volatility, hue=Direction, data=avg_volatility_direction,
                kind=bar, palette=['#646464', '#AAAAAA'], edgecolor=black, height=6, aspect=1.5)

# set axis labels
g.set_axis_labels('', 'Average Implied Volatility')

# adjust the legend to be on the top right within the grid
g._legend.set_title('Direction of Return')
g._legend.set_frame_on(True)
# position the legend within the grid, top right
g._legend.set_bbox_to_anchor((0.8, 0.85))  # relative to the axes' coordinates

# set the fontsize for x-axis labels
plt.setp(g.ax.get_xticklabels(), fontsize=plot_text_size)  # adjust fontsize to your preference

plt.grid(linestyle='dotted')

# save plot
plt.savefig(path + 'volatility_by_direction', dpi=500)

# display the plot
plt.show()

# %% [markdown]
# ## Option Price Distribution 2020-2023

# %%
plot_text_size = 14

# %% [markdown]
# ### All Options

# %% [markdown]
# 2021-2023

# %%
import matplotlib.pyplot as plt
sns.set_theme(style=whitegrid)


plt.figure(figsize=(10, 6))

# plot histogram of price data
plt.hist(df_model['price'], bins=50, color='#646464', edgecolor='black')

# set x-axis label
plt.xlabel('Price', fontsize=plot_text_size)
# set y-axis label
plt.ylabel('Frequency', fontsize=plot_text_size)

# add grid with dotted lines
plt.grid(linestyle='dotted')

# adjust layout
plt.tight_layout()

# save plot
plt.savefig(path + 'price_dist_all_options', dpi=500)

# display plot
plt.show()

# %% [markdown]
# 2020 Feb-April

# %%
import matplotlib.pyplot as plt
sns.set_theme(style=whitegrid)

plt.figure(figsize=(10, 6))

# plot histogram of price data for Feb-Mar
plt.hist(df_model_test_feb_mar['price'], bins=50, color='#646464', edgecolor='black')

# set x-axis label
plt.xlabel('Price', fontsize=plot_text_size)
# set y-axis label
plt.ylabel('Frequency', fontsize=plot_text_size)

# add grid with dotted lines
plt.grid(linestyle='dotted')

# adjust layout
plt.tight_layout()

# save plot
plt.savefig(path + 'price_dist_all_option_feb_mar', dpi=500)

# display plot
plt.show()

# %% [markdown]
# ### Filter

# %%
# moneyness
df_model_filtered = df_model[df_model['moneyness'] <= 1]
df_model_test_feb_mar_filtered = df_model_test_feb_mar[df_model_test_feb_mar['moneyness'] <= 1]
bsm_df = bsm_df[bsm_df['moneyness'] <= 1]

# price
df_model_filtered = df_model_filtered[df_model_filtered['price'] >= 1]
df_model_test_feb_mar_filtered = df_model_test_feb_mar_filtered [df_model_test_feb_mar_filtered ['price'] >= 1]
bsm_df = bsm_df[bsm_df['price'] >= 1]

# %% [markdown]
# ### Filtered Options

# %% [markdown]
# 2021-2023

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

plt.figure(figsize=(10, 6))

# plot histogram of filtered price data
plt.hist(df_model_filtered['price'], bins=50, color='#646464', edgecolor='black')

# set x-axis label
plt.xlabel('Price', fontsize=plot_text_size)
# set y-axis label
plt.ylabel('Frequency', fontsize=plot_text_size)

# add grid with dotted lines
plt.grid(linestyle='dotted')

# adjust layout
plt.tight_layout()

# save plot
plt.savefig(path + 'price_dist_filtered_option', dpi=500)

# display plot
plt.show()
# Out:
# <ipython-input-190-a286b436fdd3>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# 2020 Feb-April

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

plt.figure(figsize=(10, 6))

# plot histogram of filtered price data for Feb-Mar
plt.hist(df_model_test_feb_mar_filtered['price'], bins=50, color='#646464', edgecolor='black')

# set x-axis label
plt.xlabel('Price', fontsize=plot_text_size)
# set y-axis label
plt.ylabel('Frequency', fontsize=plot_text_size)

# add grid with dotted lines
plt.grid(linestyle='dotted')

# adjust layout
plt.tight_layout()

# save plot
plt.savefig(path + 'price_dist_filtered_option_feb_mar', dpi=500)

# display plot
plt.show()
# Out:
# <ipython-input-191-1342333c57d5>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ### Filtered Options LOG

# %%
import numpy as np
# log price
df_model_filtered['log_price'] = np.log(df_model_filtered['price'])
df_model_test_feb_mar_filtered['log_price'] = np.log(df_model_test_feb_mar_filtered['price'])

# %% [markdown]
# 2021-2023

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

plt.figure(figsize=(10, 6))

# plot histogram of log-transformed filtered price data
plt.hist(df_model_filtered['log_price'], bins=50, color='#646464', edgecolor='black')

# set x-axis label
plt.xlabel('Price', fontsize=plot_text_size)
# set y-axis label
plt.ylabel('Frequency', fontsize=plot_text_size)

# add grid with dotted lines
plt.grid(linestyle='dotted')

# adjust layout
plt.tight_layout()

# save plot
plt.savefig(path + 'price_dist_log_filtered_option', dpi=500)

# display plot
plt.show()
# Out:
# <ipython-input-193-b0a8a0eff30e>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# 2020 Feb-Apr

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

plt.figure(figsize=(10, 6))

# plot histogram of log-transformed filtered price data for Feb-Mar
plt.hist(df_model_test_feb_mar_filtered['log_price'], bins=50, color='#646464', edgecolor='black')

# set x-axis label
plt.xlabel('Price', fontsize=plot_text_size)
# set y-axis label
plt.ylabel('Frequency', fontsize=plot_text_size)

# add grid with dotted lines
plt.grid(linestyle='dotted')

# adjust layout
plt.tight_layout()

# save plot
plt.savefig(path + 'price_dist_filtered_log_option_feb_mar', dpi=500)

# display plot
plt.show()
# Out:
# <ipython-input-194-45c729a7364a>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# # Density Function (Filtered Options)

# %% [markdown]
# ## 2020-2023

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm, skew, kurtosis
import seaborn as sns
import numpy as np

# returns
daily_returns = bsm_df['sprtrn']

# annual volatility
annual_volatility = np.std(daily_returns) * np.sqrt(252)

# skewness and kurtosis
skewness = skew(daily_returns)
kurtosis_value = kurtosis(daily_returns)

# style
sns.set(style='whitegrid')

# figure
fig, ax = plt.subplots(figsize=(10, 6))

# histogram daily returns
counts, bins, ignored = ax.hist(daily_returns, bins=756, density=True, color='gray', alpha=0.5, edgecolor='black', label='Daily Returns')

# normal distribution over histogram
mu, sigma = norm.fit(daily_returns)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, sigma)
ax.plot(x, p, 'k', linewidth=2, label=f'Normal Distribution\nμ={mu:.2f}, σ={sigma:.2f}')

# legend
ax.legend(loc='upper left', frameon=True, fontsize=plot_text_size)

# add skewness and kurtosis in box
textstr = f'Skewness: {skewness:>6.2f}\nKurtosis: {kurtosis_value:>9.2f}'
props = dict(boxstyle='round', edgecolor='gray', alpha = 0.5, facecolor='white')

# Place the text box in upper left in axes coords
ax.text(0.02, 0.75, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

# grid
ax.grid(linestyle='dotted')

# x-axis limit
ax.set_xlim(left=-0.15, right=0.15)

# y-axis limit
ax.set_ylim(bottom=0, top=120)

# save
plt.savefig(path+'distribution_20_23', dpi=500)

# show
plt.show()

# annual volatility
print(f"Annual Volatility: {annual_volatility:.2%}")
# Out:
# Annual Volatility: 31.67%

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm, skew, kurtosis
import seaborn as sns
import numpy as np

# returns
daily_returns = bsm_df['sprtrn']

# annual volatility
annual_volatility = np.std(daily_returns) * np.sqrt(252)

# skewness and kurtosis
skewness = skew(daily_returns)
kurtosis_value = kurtosis(daily_returns)

# style
sns.set(style='whitegrid')

# figure
fig, ax = plt.subplots(figsize=(10, 6))

# histogram daily returns
counts, bins, ignored = ax.hist(daily_returns, bins=252, density=True, color='gray', alpha=0.5, edgecolor='black', label='Daily Returns')

# normal distribution over histogram
mu, sigma = norm.fit(daily_returns)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, sigma)
ax.plot(x, p, 'k', linewidth=2, label=f'Normal Distribution\nμ={mu:.2f}, σ={sigma:.2f}')

# legend
ax.legend(loc='upper left', frameon=True, fontsize=plot_text_size)

# add skewness and kurtosis in box
textstr = f'Skewness: {skewness:>6.2f}\nKurtosis: {kurtosis_value:>9.2f}'
props = dict(boxstyle='round', edgecolor='gray', alpha = 0.5, facecolor='white')

# Place the text box in upper left in axes coords
ax.text(0.02, 0.75, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

# grid
ax.grid(linestyle='dotted')

# save
plt.savefig(path+'distribution_20_23_zoom', dpi=500)

# show
plt.show()

# annual volatility
print(f"Annual Volatility: {annual_volatility:.2%}")
# Out:
# Annual Volatility: 31.67%

# %% [markdown]
# ## 2020

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm, skew, kurtosis
import seaborn as sns
import numpy as np

# year filter
filtered_df = bsm_df[bsm_df['date'].dt.year == 2020]

# returns in filtered year
daily_returns = filtered_df['sprtrn']

# annual volatility
annual_volatility = np.std(daily_returns) * np.sqrt(252)

# skewness and kurtosis
skewness = skew(daily_returns)
kurtosis_value = kurtosis(daily_returns)

# style
sns.set(style='whitegrid')

# figure
fig, ax = plt.subplots(figsize=(10, 6))

# histogram daily returns
counts, bins, ignored = ax.hist(daily_returns, bins=252, density=True, color='gray', alpha=0.5, edgecolor='black', label='Daily Returns')

# normal distribution over histogram
mu, sigma = norm.fit(daily_returns)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, sigma)
ax.plot(x, p, 'k', linewidth=2, label=f'Normal Distribution\nμ={mu:.2f}, σ={sigma:.2f}')

# legend
ax.legend(loc='upper left', frameon=True, fontsize=plot_text_size)

# add skewness and kurtosis in box
textstr = f'Skewness: {skewness:>6.2f}\nKurtosis: {kurtosis_value:>9.2f}'
props = dict(boxstyle='round', edgecolor='gray', alpha = 0.5, facecolor='white')

# Place the text box in upper left in axes coords
ax.text(0.02, 0.75, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

# grid
ax.grid(linestyle='dotted')

# x-axis limit
ax.set_xlim(left=-0.15, right=0.15)

# y-axis limit
ax.set_ylim(bottom=0, top=120)

# save
plt.savefig(path+'distribution_20', dpi=500)

# show
plt.show()

# annual volatility
print(f"Annual Volatility: {annual_volatility:.2%}")
# Out:
# Annual Volatility: 46.84%

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm, skew, kurtosis
import seaborn as sns
import numpy as np

# year filter
filtered_df = bsm_df[bsm_df['date'].dt.year == 2020]

# returns in filtered year
daily_returns = filtered_df['sprtrn']

# annual volatility
annual_volatility = np.std(daily_returns) * np.sqrt(252)

# skewness and kurtosis
skewness = skew(daily_returns)
kurtosis_value = kurtosis(daily_returns)

# style
sns.set(style='whitegrid')

# figure
fig, ax = plt.subplots(figsize=(10, 6))

# histogram daily returns
counts, bins, ignored = ax.hist(daily_returns, bins=252, density=True, color='gray', alpha=0.5, edgecolor='black', label='Daily Returns')

# normal distribution over histogram
mu, sigma = norm.fit(daily_returns)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, sigma)
ax.plot(x, p, 'k', linewidth=2, label=f'Normal Distribution\nμ={mu:.2f}, σ={sigma:.2f}')

# legend
ax.legend(loc='upper left', frameon=True, fontsize=plot_text_size)

# add skewness and kurtosis in box
textstr = f'Skewness: {skewness:>6.2f}\nKurtosis: {kurtosis_value:>9.2f}'
props = dict(boxstyle='round', edgecolor='gray', alpha = 0.5, facecolor='white')

# Place the text box in upper left in axes coords
ax.text(0.02, 0.75, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

# grid
ax.grid(linestyle='dotted')

# save
plt.savefig(path+'distribution_20_zoom', dpi=500)

# show
plt.show()

# annual volatility
print(f"Annual Volatility: {annual_volatility:.2%}")
# Out:
# Annual Volatility: 46.84%

# %% [markdown]
# ## 2021

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm, skew, kurtosis
import seaborn as sns
import numpy as np

# year filter
filtered_df = bsm_df[bsm_df['date'].dt.year == 2021]

# returns in filtered year
daily_returns = filtered_df['sprtrn']

# annual volatility
annual_volatility = np.std(daily_returns) * np.sqrt(252)

# skewness and kurtosis
skewness = skew(daily_returns)
kurtosis_value = kurtosis(daily_returns)

# style
sns.set(style='whitegrid')

# figure
fig, ax = plt.subplots(figsize=(10, 6))

# histogram daily returns
counts, bins, ignored = ax.hist(daily_returns, bins=252, density=True, color='gray', alpha=0.5, edgecolor='black', label='Daily Returns')

# normal distribution over histogram
mu, sigma = norm.fit(daily_returns)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, sigma)
ax.plot(x, p, 'k', linewidth=2, label=f'Normal Distribution\nμ={mu:.2f}, σ={sigma:.2f}')

# legend
ax.legend(loc='upper left', frameon=True, fontsize=plot_text_size)

# add skewness and kurtosis in box
textstr = f'Skewness: {skewness:>6.2f}\nKurtosis: {kurtosis_value:>9.2f}'
props = dict(boxstyle='round', edgecolor='gray', alpha = 0.5, facecolor='white')

# Place the text box in upper left in axes coords
ax.text(0.02, 0.75, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

# grid
ax.grid(linestyle='dotted')

# x-axis limit
ax.set_xlim(left=-0.15, right=0.15)

# y-axis limit
ax.set_ylim(bottom=0, top=120)

# save
plt.savefig(path+'distribution_21', dpi=500)

# show
plt.show()

# annual volatility
print(f"Annual Volatility: {annual_volatility:.2%}")
# Out:
# Annual Volatility: 14.34%

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm, skew, kurtosis
import seaborn as sns
import numpy as np

# year filter
filtered_df = bsm_df[bsm_df['date'].dt.year == 2021]

# returns in filtered year
daily_returns = filtered_df['sprtrn']

# annual volatility
annual_volatility = np.std(daily_returns) * np.sqrt(252)

# skewness and kurtosis
skewness = skew(daily_returns)
kurtosis_value = kurtosis(daily_returns)

# style
sns.set(style='whitegrid')

# figure
fig, ax = plt.subplots(figsize=(10, 6))

# histogram daily returns
counts, bins, ignored = ax.hist(daily_returns, bins=252, density=True, color='gray', alpha=0.5, edgecolor='black', label='Daily Returns')

# normal distribution over histogram
mu, sigma = norm.fit(daily_returns)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, sigma)
ax.plot(x, p, 'k', linewidth=2, label=f'Normal Distribution\nμ={mu:.2f}, σ={sigma:.2f}')

# legend
ax.legend(loc='upper left', frameon=True, fontsize=plot_text_size)

# add skewness and kurtosis in box
textstr = f'Skewness: {skewness:>6.2f}\nKurtosis: {kurtosis_value:>9.2f}'
props = dict(boxstyle='round', edgecolor='gray', alpha = 0.5, facecolor='white')

# Place the text box in upper left in axes coords
ax.text(0.02, 0.75, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

# grid
ax.grid(linestyle='dotted')

# save
plt.savefig(path+'distribution_21_zoom', dpi=500)

# show
plt.show()

# annual volatility
print(f"Annual Volatility: {annual_volatility:.2%}")
# Out:
# Annual Volatility: 14.34%

# %% [markdown]
# ##2022

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm, skew, kurtosis
import seaborn as sns
import numpy as np

# year filter
filtered_df = bsm_df[bsm_df['date'].dt.year == 2022]

# returns in filtered year
daily_returns = filtered_df['sprtrn']

# annual volatility
annual_volatility = np.std(daily_returns) * np.sqrt(252)

# skewness and kurtosis
skewness = skew(daily_returns)
kurtosis_value = kurtosis(daily_returns)

# style
sns.set(style='whitegrid')

# figure
fig, ax = plt.subplots(figsize=(10, 6))

# histogram daily returns
counts, bins, ignored = ax.hist(daily_returns, bins=252, density=True, color='gray', alpha=0.5, edgecolor='black', label='Daily Returns')

# normal distribution over histogram
mu, sigma = norm.fit(daily_returns)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, sigma)
ax.plot(x, p, 'k', linewidth=2, label=f'Normal Distribution\nμ={mu:.2f}, σ={sigma:.2f}')

# legend
ax.legend(loc='upper left', frameon=True, fontsize=plot_text_size)

# add skewness and kurtosis in box
textstr = f'Skewness: {skewness:>6.2f}\nKurtosis: {kurtosis_value:>9.2f}'
props = dict(boxstyle='round', edgecolor='gray', alpha = 0.5, facecolor='white')

# Place the text box in upper left in axes coords
ax.text(0.02, 0.75, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

# grid
ax.grid(linestyle='dotted')

# x-axis limit
ax.set_xlim(left=-0.15, right=0.15)

# y-axis limit
ax.set_ylim(bottom=0, top=120)

# save
plt.savefig(path+'distribution_22', dpi=500)

# show
plt.show()

# annual volatility
print(f"Annual Volatility: {annual_volatility:.2%}")
# Out:
# Annual Volatility: 24.69%

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm, skew, kurtosis
import seaborn as sns
import numpy as np

# year filter
filtered_df = bsm_df[bsm_df['date'].dt.year == 2022]

# returns in filtered year
daily_returns = filtered_df['sprtrn']

# annual volatility
annual_volatility = np.std(daily_returns) * np.sqrt(252)

# skewness and kurtosis
skewness = skew(daily_returns)
kurtosis_value = kurtosis(daily_returns)

# style
sns.set(style='whitegrid')

# figure
fig, ax = plt.subplots(figsize=(10, 6))

# histogram daily returns
counts, bins, ignored = ax.hist(daily_returns, bins=252, density=True, color='gray', alpha=0.5, edgecolor='black', label='Daily Returns')

# normal distribution over histogram
mu, sigma = norm.fit(daily_returns)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, sigma)
ax.plot(x, p, 'k', linewidth=2, label=f'Normal Distribution\nμ={mu:.2f}, σ={sigma:.2f}')

# legend
ax.legend(loc='upper left', frameon=True, fontsize=plot_text_size)

# add skewness and kurtosis in box
textstr = f'Skewness: {skewness:>6.2f}\nKurtosis: {kurtosis_value:>9.2f}'
props = dict(boxstyle='round', edgecolor='gray', alpha = 0.5, facecolor='white')

# Place the text box in upper left in axes coords
ax.text(0.02, 0.75, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

# grid
ax.grid(linestyle='dotted')

# save
plt.savefig(path+'distribution_22_zoom', dpi=500)

# show
plt.show()

# annual volatility
print(f"Annual Volatility: {annual_volatility:.2%}")
# Out:
# Annual Volatility: 24.69%

# %% [markdown]
# # Final Data

# %%
# maturity
bsm_df["maturity"] = bsm_df["maturity"] / 365

# %%
bsm_df.head()
# Out:
#          date  strike_price  best_bid  best_offer  impl_volatility     delta  \
# 56 2020-01-02        3260.0      21.8        22.2         0.090910  0.487388
# 57 2020-01-02        3265.0      19.0        19.4         0.088994  0.452029
# 58 2020-01-02        3270.0      16.4        16.8         0.087143  0.415642
# 59 2020-01-02        3275.0      14.0        14.4         0.085326  0.378539
# 60 2020-01-02        3280.0      11.9        12.2         0.083729  0.341450
#
#        gamma      vega     theta              issuer  price  maturity    vix  \
# 56  0.006870  254.2476 -298.9959  CBOE S&P 500 INDEX  22.00  0.041096  12.47
# 57  0.006971  252.5506 -290.8645  CBOE S&P 500 INDEX  19.20  0.041096  12.47
# 58  0.007010  248.6983 -280.5834  CBOE S&P 500 INDEX  16.60  0.041096  12.47
# 59  0.006982  242.5367 -268.0264  CBOE S&P 500 INDEX  14.20  0.041096  12.47
# 60  0.006867  234.0657 -253.9162  CBOE S&P 500 INDEX  12.05  0.041096  12.47
#
# ...

# %%
import scipy.stats as stats
import math

def black_scholes(S, K, T, r, sigma, option='call'):
    """
    black_scholes calculates the price of a call or put option using the Black-Scholes formula.

    :param S: Current stock price
    :param K: Option strike price
    :param T: Time to expiration in years
    :param r: Risk-free interest rate
    :param sigma: Volatility of the stock
    :param option: Type of option ('call' or 'put')
    :return: Price of the option
    """
    # calculate d1 and d2 for the option's price
    d1 = (math.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * math.sqrt(T))
    d2 = (math.log(S / K) + (r - 0.5 * sigma ** 2) * T) / (sigma * math.sqrt(T))

    # compute and return the option's price based on option type
    if option == 'call':
        return S * stats.norm.cdf(d1) - K * math.exp(-r * T) * stats.norm.cdf(d2)
    elif option == 'put':
        return K * math.exp(-r * T) * stats.norm.cdf(-d2) - S * stats.norm.cdf(-d1)

    # error handling
    else:
        raise ValueError("Invalid option type. Use 'call' or 'put'.")

# %%
import pandas as pd

def find_atm_calls(df):
    """
    find_atm_calls looks for a call with the delta closest to 0.5.

    :param df: input dafaframe
    :return: pandas Series representing the row that is closest to 0.5
    """
    # calculate difference delta and 0.5
    abs_delta_diff = df['delta'].sub(0.5).abs()

    # look for index
    return df.loc[abs_delta_diff.idxmin()]

# %%
# group by date and apply find_atm_calls function to find at-the-money calls
atm_calls = bsm_df.groupby('date', as_index=False).apply(find_atm_calls).reset_index(drop=True)

# calculate daily average implied volatility for at-the-money calls
daily_vola_atm = atm_calls.groupby('date')['impl_volatility'].mean().reset_index()

# rename column to Vola_ATM
daily_vola_atm.rename(columns={'impl_volatility': 'Vola_ATM'}, inplace=True)

# merge daily average implied volatility with the original dataframe
bsm_df = pd.merge(bsm_df, daily_vola_atm, on='date', how='left')

# %%
import pandas as pd

# calculate daily average implied volatility for all options
daily_vola_all = bsm_df.groupby('date')['impl_volatility'].mean().reset_index()

# rename column to Vola_ALL
daily_vola_all.rename(columns={'impl_volatility': 'Vola_ALL'}, inplace=True)

# merge daily average implied volatility with the original dataframe
bsm_df = pd.merge(bsm_df, daily_vola_all, on='date', how='left')

# %%
# initialize an empty list to store BSM values for ATM options
bsm_values_ATM = []

# iterate over each row in the dataframe
for index, row in bsm_df.iterrows():
    # calculate the Black-Scholes value using Vola_ATM for each row
    bsm_value = black_scholes(row["spindx"], row["strike_price"], row["maturity"], row["t30ret"], row["Vola_ATM"], 'call')
    # append the calculated value to the list
    bsm_values_ATM.append(bsm_value)

# add the calculated BSM values as a new column to the dataframe
bsm_df["BSM_Vola_ATM"] = bsm_values_ATM

# %%
# initialize an empty list to store BSM values for all options
bsm_values_ALL = []

# iterate over each row in the dataframe
for index, row in bsm_df.iterrows():
    # calculate the Black-Scholes value using Vola_ALL for each row
    bsm_value = black_scholes(row["spindx"], row["strike_price"], row["maturity"], row["t30ret"], row["Vola_ALL"], 'call')
    # append the calculated value to the list
    bsm_values_ALL.append(bsm_value)

# add the calculated BSM values as a new column to the dataframe
bsm_df["BSM_Vola_ALL"] = bsm_values_ALL

# %%
bsm_df
# Out:
#              date  strike_price  best_bid  best_offer  impl_volatility  \
# 0      2020-01-02        3260.0     21.80       22.20         0.090910
# 1      2020-01-02        3265.0     19.00       19.40         0.088994
# 2      2020-01-02        3270.0     16.40       16.80         0.087143
# 3      2020-01-02        3275.0     14.00       14.40         0.085326
# 4      2020-01-02        3280.0     11.90       12.20         0.083729
# ...           ...           ...       ...         ...              ...
# 430341 2022-12-30        4230.0      1.65        1.85         0.173057
# 430342 2022-12-30        4240.0      1.50        1.65         0.173741
# 430343 2022-12-30        4250.0      1.35        1.50         0.174571
# 430344 2022-12-30        4260.0      1.20        1.35         0.175111
# 430345 2022-12-30        4275.0      1.05        1.15         0.176422
#
#            delta     gamma       vega      theta              issuer  ...  \
# ...

# %%
# initialize an empty list to store BSM values
bsm_values = []

# iterate over each row in the dataframe
for index, row in bsm_df.iterrows():
    # calculate the Black-Scholes value using the implied volatility for each row
    bsm_value = black_scholes(row["spindx"], row["strike_price"], row["maturity"], row["t30ret"], row["impl_volatility"], 'call')
    # append the calculated value to the list
    bsm_values.append(bsm_value)

# add the calculated BSM values as a new column to the dataframe
bsm_df["BSM"] = bsm_values

# %%
bsm_df
# Out:
#              date  strike_price  best_bid  best_offer  impl_volatility  \
# 0      2020-01-02        3260.0     21.80       22.20         0.090910
# 1      2020-01-02        3265.0     19.00       19.40         0.088994
# 2      2020-01-02        3270.0     16.40       16.80         0.087143
# 3      2020-01-02        3275.0     14.00       14.40         0.085326
# 4      2020-01-02        3280.0     11.90       12.20         0.083729
# ...           ...           ...       ...         ...              ...
# 430341 2022-12-30        4230.0      1.65        1.85         0.173057
# 430342 2022-12-30        4240.0      1.50        1.65         0.173741
# 430343 2022-12-30        4250.0      1.35        1.50         0.174571
# 430344 2022-12-30        4260.0      1.20        1.35         0.175111
# 430345 2022-12-30        4275.0      1.05        1.15         0.176422
#
#            delta     gamma       vega      theta              issuer  ...  \
# ...

# %%
# add log price, strike price, index level
bsm_df['log_price'] = np.log(bsm_df['price'])
bsm_df['log_strike_price'] = np.log(bsm_df['strike_price'])
bsm_df['log_spindx'] = np.log(bsm_df['spindx'])

# %%
bsm_df

# %%
bsm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 430346 entries, 0 to 430345
# Data columns (total 25 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              430346 non-null  datetime64[ns]
#  1   strike_price      430346 non-null  float64
#  2   best_bid          430346 non-null  float64
#  3   best_offer        430346 non-null  float64
#  4   impl_volatility   430346 non-null  float64
#  5   delta             430346 non-null  float64
#  6   gamma             430346 non-null  float64
#  7   vega              430346 non-null  float64
#  8   theta             430346 non-null  float64
#  9   issuer            430346 non-null  object
#  10  price             430346 non-null  float64
#  11  maturity          430346 non-null  float64
#  12  vix               430346 non-null  float64
#  13  t30ret            430346 non-null  float64
#  14  spindx            430346 non-null  float64
# ...

# %%
# save df
bsm_df.to_csv("/content/drive/MyDrive/Colab Notebooks/BAThesis/call_bsm_dataset_24_04_24.csv", index=False)
